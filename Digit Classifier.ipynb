# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
X = data.images
y = data.target
print(X[0:9])
print()
print(y[0:9])
# Out:
# [[[ 0.  0.  5. 13.  9.  1.  0.  0.]
#   [ 0.  0. 13. 15. 10. 15.  5.  0.]
#   [ 0.  3. 15.  2.  0. 11.  8.  0.]
#   [ 0.  4. 12.  0.  0.  8.  8.  0.]
#   [ 0.  5.  8.  0.  0.  9.  8.  0.]
#   [ 0.  4. 11.  0.  1. 12.  7.  0.]
#   [ 0.  2. 14.  5. 10. 12.  0.  0.]
#   [ 0.  0.  6. 13. 10.  0.  0.  0.]]
#
#  [[ 0.  0.  0. 12. 13.  5.  0.  0.]
#   [ 0.  0.  0. 11. 16.  9.  0.  0.]
#   [ 0.  0.  3. 15. 16.  6.  0.  0.]
#   [ 0.  7. 15. 16. 16.  2.  0.  0.]
#   [ 0.  0.  1. 16. 16.  3.  0.  0.]
#   [ 0.  0.  1. 16. 16.  6.  0.  0.]
#   [ 0.  0.  1. 16. 16.  6.  0.  0.]
#   [ 0.  0.  0. 11. 16. 10.  0.  0.]]
#
#  [[ 0.  0.  0.  4. 15. 12.  0.  0.]
#   [ 0.  0.  3. 16. 15. 14.  0.  0.]
#   [ 0.  0.  8. 13.  8. 16.  0.  0.]
#   [ 0.  0.  1.  6. 15. 11.  0.  0.]
#   [ 0.  1.  8. 13. 15.  1.  0.  0.]
#   [ 0.  9. 16. 16.  5.  0.  0.  0.]
#   [ 0.  3. 13. 16. 16. 11.  5.  0.]
#   [ 0.  0.  0.  3. 11. 16.  9.  0.]]
#
#  [[ 0.  0.  7. 15. 13.  1.  0.  0.]
#   [ 0.  8. 13.  6. 15.  4.  0.  0.]
# ...

# %%
X = X.reshape(X.shape[0],-1)
X.shape
# Out:
# (1797, 64)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# **KNN**

# %%
from sklearn.metrics import accuracy_score

# %%
#Checking value for K
ks = 15
mean_acc = np.zeros(ks-1)

for k in range(1,ks):
    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(X_train, y_train)
    y_caps = neigh.predict(X_test)
    mean_acc[k-1] = accuracy_score(y_test, y_caps)
print(mean_acc)
k = mean_acc.argmax()+1
print('K : ',k)
# Out:
# [0.98222222 0.98444444 0.98666667 0.98666667 0.99333333 0.99555556
#  0.99333333 0.98888889 0.98666667 0.98666667 0.98       0.98
#  0.98       0.98222222]
# K :  6

# %%
neigh = KNeighborsClassifier(n_neighbors=k).fit(X_train, y_train)
y_caps = neigh.predict(X_test)

# %%
from sklearn.metrics import  classification_report
print("\t\t\tEVALUATION TABLE")
print(classification_report(y_test, y_caps))
# Out:
# 			EVALUATION TABLE
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       0.97      1.00      0.99        37
#            2       1.00      1.00      1.00        38
#            3       0.98      1.00      0.99        46
#            4       0.98      1.00      0.99        55
#            5       0.98      1.00      0.99        59
#            6       1.00      1.00      1.00        45
#            7       1.00      0.98      0.99        41
#            8       0.97      0.97      0.97        38
#            9       0.98      0.92      0.95        48
#
#     accuracy                           0.99       450
#    macro avg       0.99      0.99      0.99       450
# weighted avg       0.99      0.99      0.99       450

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
logis = LogisticRegression(C=10, solver='liblinear',multi_class='auto')
logis.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_caps2 = logis.predict(X_test)

# %%
from sklearn.metrics import  classification_report
print("\t\t\tEVALUATION TABLE")
print(classification_report(y_test, y_caps))
# Out:
# 			EVALUATION TABLE
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       0.97      1.00      0.99        37
#            2       1.00      1.00      1.00        38
#            3       0.98      1.00      0.99        46
#            4       0.98      1.00      0.99        55
#            5       0.98      1.00      0.99        59
#            6       1.00      1.00      1.00        45
#            7       1.00      0.98      0.99        41
#            8       0.97      0.97      0.97        38
#            9       0.98      0.92      0.95        48
#
#     accuracy                           0.99       450
#    macro avg       0.99      0.99      0.99       450
# weighted avg       0.99      0.99      0.99       450
